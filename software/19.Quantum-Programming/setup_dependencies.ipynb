# %%
# !pip3 install qiskit
# Out:
# Requirement already satisfied: qiskit in /home/naadi/.local/lib/python3.8/site-packages (0.28.0)
# Requirement already satisfied: qiskit-ignis==0.6.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit) (0.6.0)
# Requirement already satisfied: qiskit-ibmq-provider==0.15.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit) (0.15.0)
# Requirement already satisfied: qiskit-aer==0.8.2 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit) (0.8.2)
# Requirement already satisfied: qiskit-terra==0.18.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit) (0.18.0)
# Requirement already satisfied: qiskit-aqua==0.9.4 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit) (0.9.4)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/lib/python3/dist-packages (from qiskit-ignis==0.6.0->qiskit) (45.2.0)
# Requirement already satisfied: scipy!=0.19.1,>=0.19 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ignis==0.6.0->qiskit) (1.5.2)
# Requirement already satisfied: numpy>=1.13 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ignis==0.6.0->qiskit) (1.20.0)
# Requirement already satisfied: retworkx>=0.8.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ignis==0.6.0->qiskit) (0.9.0)
# Requirement already satisfied: websocket-client>=1.0.1 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.15.0->qiskit) (1.1.0)
# Requirement already satisfied: urllib3>=1.21.1 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.15.0->qiskit) (1.25.10)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.15.0->qiskit) (2.8.1)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.15.0->qiskit) (1.1.0)
# Requirement already satisfied: requests>=2.19 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.15.0->qiskit) (2.23.0)
# Requirement already satisfied: pybind11>=2.6 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aer==0.8.2->qiskit) (2.7.0)
# Requirement already satisfied: python-constraint>=1.4 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit) (1.4.0)
# Requirement already satisfied: symengine>0.7; platform_machine == "x86_64" or platform_machine == "aarch64" or platform_machine == "ppc64le" or platform_machine == "amd64" or platform_machine == "arm64" in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit) (0.7.2)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit) (1.1.0)
# Requirement already satisfied: jsonschema>=2.6 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit) (3.2.0)
# Requirement already satisfied: sympy>=1.3 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit) (1.8)
# Requirement already satisfied: dill>=0.3 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit) (0.3.4)
# Requirement already satisfied: fastjsonschema>=2.10 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit) (2.15.1)
# Requirement already satisfied: psutil>=5 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit) (5.8.0)
# Requirement already satisfied: ply>=3.10 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit) (3.11)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit) (0.24.2)
# Requirement already satisfied: dlx<=1.0.4 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit) (1.0.4)
# Requirement already satisfied: yfinance<0.1.63 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit) (0.1.62)
# Requirement already satisfied: fastdtw<=0.3.4 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit) (0.3.4)
# Requirement already satisfied: h5py<3.3.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit) (3.2.1)
# Requirement already satisfied: pandas in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit) (1.2.1)
# Requirement already satisfied: quandl in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit) (3.6.1)
# Requirement already satisfied: docplex>=2.21.207 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit) (2.21.207)
# Requirement already satisfied: six>=1.5 in /home/naadi/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.15.0->qiskit) (1.15.0)
# Requirement already satisfied: cryptography>=1.3 in /usr/lib/python3/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.15.0->qiskit) (2.8)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /home/naadi/.local/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.15.0->qiskit) (1.5.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/lib/python3/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.15.0->qiskit) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.15.0->qiskit) (2019.11.28)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.15.0->qiskit) (2.8)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/naadi/.local/lib/python3.8/site-packages (from jsonschema>=2.6->qiskit-terra==0.18.0->qiskit) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/lib/python3/dist-packages (from jsonschema>=2.6->qiskit-terra==0.18.0->qiskit) (19.3.0)
# Requirement already satisfied: mpmath>=0.19 in /home/naadi/.local/lib/python3.8/site-packages (from sympy>=1.3->qiskit-terra==0.18.0->qiskit) (1.2.1)
# Requirement already satisfied: joblib>=0.11 in /home/naadi/.local/lib/python3.8/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.4->qiskit) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/naadi/.local/lib/python3.8/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.4->qiskit) (2.2.0)
# Requirement already satisfied: multitasking>=0.0.7 in /home/naadi/.local/lib/python3.8/site-packages (from yfinance<0.1.63->qiskit-aqua==0.9.4->qiskit) (0.0.9)
# Requirement already satisfied: lxml>=4.5.1 in /home/naadi/.local/lib/python3.8/site-packages (from yfinance<0.1.63->qiskit-aqua==0.9.4->qiskit) (4.6.3)
# Requirement already satisfied: pytz>=2017.3 in /home/naadi/.local/lib/python3.8/site-packages (from pandas->qiskit-aqua==0.9.4->qiskit) (2020.1)
# Requirement already satisfied: inflection>=0.3.1 in /home/naadi/.local/lib/python3.8/site-packages (from quandl->qiskit-aqua==0.9.4->qiskit) (0.5.1)
# Requirement already satisfied: more-itertools in /usr/lib/python3/dist-packages (from quandl->qiskit-aqua==0.9.4->qiskit) (4.2.0)

# %%
# !pip3 install git+https://github.com/qiskit-community/qiskit-textbook.git#subdirectory=qiskit-textbook-src
# Out:
# Collecting git+https://github.com/qiskit-community/qiskit-textbook.git#subdirectory=qiskit-textbook-src
#   Cloning https://github.com/qiskit-community/qiskit-textbook.git to /tmp/pip-req-build-ywuq2u90
#   Running command git clone -q https://github.com/qiskit-community/qiskit-textbook.git /tmp/pip-req-build-ywuq2u90
# Requirement already satisfied (use --upgrade to upgrade): qiskit-textbook==0.1.0 from git+https://github.com/qiskit-community/qiskit-textbook.git#subdirectory=qiskit-textbook-src in /home/naadi/.local/lib/python3.8/site-packages
# Requirement already satisfied: ipython in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-textbook==0.1.0) (7.18.1)
# Requirement already satisfied: ipywidgets in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-textbook==0.1.0) (7.6.3)
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (from qiskit-textbook==0.1.0) (3.1.2)
# Requirement already satisfied: numpy in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-textbook==0.1.0) (1.20.0)
# Requirement already satisfied: qiskit in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-textbook==0.1.0) (0.28.0)
# Requirement already satisfied: pickleshare in /home/naadi/.local/lib/python3.8/site-packages (from ipython->qiskit-textbook==0.1.0) (0.7.5)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/lib/python3/dist-packages (from ipython->qiskit-textbook==0.1.0) (4.6.0)
# Requirement already satisfied: traitlets>=4.2 in /home/naadi/.local/lib/python3.8/site-packages (from ipython->qiskit-textbook==0.1.0) (5.0.4)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from ipython->qiskit-textbook==0.1.0) (4.4.2)
# Requirement already satisfied: pygments in /home/naadi/.local/lib/python3.8/site-packages (from ipython->qiskit-textbook==0.1.0) (2.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/naadi/.local/lib/python3.8/site-packages (from ipython->qiskit-textbook==0.1.0) (3.0.7)
# Requirement already satisfied: backcall in /home/naadi/.local/lib/python3.8/site-packages (from ipython->qiskit-textbook==0.1.0) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython->qiskit-textbook==0.1.0) (45.2.0)
# Requirement already satisfied: jedi>=0.10 in /home/naadi/.local/lib/python3.8/site-packages (from ipython->qiskit-textbook==0.1.0) (0.17.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/naadi/.local/lib/python3.8/site-packages (from ipywidgets->qiskit-textbook==0.1.0) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/naadi/.local/lib/python3.8/site-packages (from ipywidgets->qiskit-textbook==0.1.0) (5.3.4)
# Requirement already satisfied: nbformat>=4.2.0 in /home/naadi/.local/lib/python3.8/site-packages (from ipywidgets->qiskit-textbook==0.1.0) (5.0.7)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /home/naadi/.local/lib/python3.8/site-packages (from ipywidgets->qiskit-textbook==0.1.0) (1.0.0)
# Requirement already satisfied: qiskit-ibmq-provider==0.15.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit->qiskit-textbook==0.1.0) (0.15.0)
# Requirement already satisfied: qiskit-terra==0.18.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit->qiskit-textbook==0.1.0) (0.18.0)
# Requirement already satisfied: qiskit-aqua==0.9.4 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit->qiskit-textbook==0.1.0) (0.9.4)
# Requirement already satisfied: qiskit-aer==0.8.2 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit->qiskit-textbook==0.1.0) (0.8.2)
# Requirement already satisfied: qiskit-ignis==0.6.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit->qiskit-textbook==0.1.0) (0.6.0)
# Requirement already satisfied: ipython-genutils in /home/naadi/.local/lib/python3.8/site-packages (from traitlets>=4.2->ipython->qiskit-textbook==0.1.0) (0.2.0)
# Requirement already satisfied: wcwidth in /home/naadi/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->qiskit-textbook==0.1.0) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/naadi/.local/lib/python3.8/site-packages (from jedi>=0.10->ipython->qiskit-textbook==0.1.0) (0.7.1)
# Requirement already satisfied: notebook>=4.4.1 in /home/naadi/.local/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (6.1.4)
# Requirement already satisfied: tornado>=4.2 in /home/naadi/.local/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets->qiskit-textbook==0.1.0) (6.0.4)
# Requirement already satisfied: jupyter-client in /home/naadi/.local/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets->qiskit-textbook==0.1.0) (6.1.7)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/naadi/.local/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->qiskit-textbook==0.1.0) (3.2.0)
# Requirement already satisfied: jupyter-core in /home/naadi/.local/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->qiskit-textbook==0.1.0) (4.6.3)
# Requirement already satisfied: urllib3>=1.21.1 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.15.0->qiskit->qiskit-textbook==0.1.0) (1.25.10)
# Requirement already satisfied: requests>=2.19 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.15.0->qiskit->qiskit-textbook==0.1.0) (2.23.0)
# Requirement already satisfied: websocket-client>=1.0.1 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.15.0->qiskit->qiskit-textbook==0.1.0) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.15.0->qiskit->qiskit-textbook==0.1.0) (2.8.1)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.15.0->qiskit->qiskit-textbook==0.1.0) (1.1.0)
# Requirement already satisfied: scipy>=1.4 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit->qiskit-textbook==0.1.0) (1.5.2)
# Requirement already satisfied: sympy>=1.3 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit->qiskit-textbook==0.1.0) (1.8)
# Requirement already satisfied: fastjsonschema>=2.10 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit->qiskit-textbook==0.1.0) (2.15.1)
# Requirement already satisfied: symengine>0.7; platform_machine == "x86_64" or platform_machine == "aarch64" or platform_machine == "ppc64le" or platform_machine == "amd64" or platform_machine == "arm64" in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit->qiskit-textbook==0.1.0) (0.7.2)
# Requirement already satisfied: psutil>=5 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit->qiskit-textbook==0.1.0) (5.8.0)
# Requirement already satisfied: dill>=0.3 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit->qiskit-textbook==0.1.0) (0.3.4)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit->qiskit-textbook==0.1.0) (1.1.0)
# Requirement already satisfied: python-constraint>=1.4 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit->qiskit-textbook==0.1.0) (1.4.0)
# Requirement already satisfied: retworkx>=0.9.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit->qiskit-textbook==0.1.0) (0.9.0)
# Requirement already satisfied: ply>=3.10 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-terra==0.18.0->qiskit->qiskit-textbook==0.1.0) (3.11)
# Requirement already satisfied: yfinance<0.1.63 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (0.1.62)
# Requirement already satisfied: h5py<3.3.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (3.2.1)
# Requirement already satisfied: quandl in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (3.6.1)
# Requirement already satisfied: docplex>=2.21.207 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (2.21.207)
# Requirement already satisfied: dlx<=1.0.4 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (1.0.4)
# Requirement already satisfied: fastdtw<=0.3.4 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (0.3.4)
# Requirement already satisfied: pandas in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (1.2.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (0.24.2)
# Requirement already satisfied: pybind11>=2.6 in /home/naadi/.local/lib/python3.8/site-packages (from qiskit-aer==0.8.2->qiskit->qiskit-textbook==0.1.0) (2.7.0)
# Requirement already satisfied: argon2-cffi in /home/naadi/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in /home/naadi/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (19.0.2)
# Requirement already satisfied: nbconvert in /home/naadi/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (6.0.5)
# Requirement already satisfied: terminado>=0.8.3 in /home/naadi/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.9.1)
# Requirement already satisfied: prometheus-client in /home/naadi/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.8.0)
# Requirement already satisfied: Send2Trash in /home/naadi/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (1.5.0)
# Requirement already satisfied: jinja2 in /home/naadi/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (2.11.2)
# Requirement already satisfied: six>=1.11.0 in /home/naadi/.local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->qiskit-textbook==0.1.0) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/naadi/.local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->qiskit-textbook==0.1.0) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/lib/python3/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->qiskit-textbook==0.1.0) (19.3.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.15.0->qiskit->qiskit-textbook==0.1.0) (2.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/lib/python3/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.15.0->qiskit->qiskit-textbook==0.1.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.15.0->qiskit->qiskit-textbook==0.1.0) (2019.11.28)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /home/naadi/.local/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.15.0->qiskit->qiskit-textbook==0.1.0) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in /usr/lib/python3/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.15.0->qiskit->qiskit-textbook==0.1.0) (2.8)
# Requirement already satisfied: mpmath>=0.19 in /home/naadi/.local/lib/python3.8/site-packages (from sympy>=1.3->qiskit-terra==0.18.0->qiskit->qiskit-textbook==0.1.0) (1.2.1)
# Requirement already satisfied: multitasking>=0.0.7 in /home/naadi/.local/lib/python3.8/site-packages (from yfinance<0.1.63->qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (0.0.9)
# Requirement already satisfied: lxml>=4.5.1 in /home/naadi/.local/lib/python3.8/site-packages (from yfinance<0.1.63->qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (4.6.3)
# Requirement already satisfied: inflection>=0.3.1 in /home/naadi/.local/lib/python3.8/site-packages (from quandl->qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (0.5.1)
# Requirement already satisfied: more-itertools in /usr/lib/python3/dist-packages (from quandl->qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (4.2.0)
# Requirement already satisfied: pytz>=2017.3 in /home/naadi/.local/lib/python3.8/site-packages (from pandas->qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (2020.1)
# Requirement already satisfied: joblib>=0.11 in /home/naadi/.local/lib/python3.8/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/naadi/.local/lib/python3.8/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.4->qiskit->qiskit-textbook==0.1.0) (2.2.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/naadi/.local/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (1.14.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/naadi/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/lib/python3/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.3)
# Requirement already satisfied: bleach in /home/naadi/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (3.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/naadi/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.8.4)
# Requirement already satisfied: defusedxml in /home/naadi/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.6.0)
# Requirement already satisfied: testpath in /home/naadi/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/naadi/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in /home/naadi/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.1.1)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /home/naadi/.local/lib/python3.8/site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/naadi/.local/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (1.1.1)
# Requirement already satisfied: pycparser in /home/naadi/.local/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (2.20)
# Requirement already satisfied: webencodings in /home/naadi/.local/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.5.1)
# Requirement already satisfied: packaging in /home/naadi/.local/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (20.4)
# Requirement already satisfied: async-generator in /home/naadi/.local/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (1.10)
# Requirement already satisfied: nest-asyncio in /home/naadi/.local/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (1.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/naadi/.local/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (2.4.7)
# Building wheels for collected packages: qiskit-textbook
#   Building wheel for qiskit-textbook (setup.py) ... done
#   Created wheel for qiskit-textbook: filename=qiskit_textbook-0.1.0-py3-none-any.whl size=16947 sha256=9562f49088c91c1127f81523a7f523f879b96010560933a747e9740e83ab92f4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ron_1u45/wheels/80/c4/dd/b7ea1ee2a7247e8997db78bc777bbe22e61ab1e5ed1c4b46e1
# Successfully built qiskit-textbook

# %%
# !pip3 install numexpr
# !pip3 install IPython
# !pip3 install plotly
# Out:
# Requirement already satisfied: numexpr in /home/naadi/.local/lib/python3.8/site-packages (2.7.3)
# Requirement already satisfied: numpy>=1.7 in /home/naadi/.local/lib/python3.8/site-packages (from numexpr) (1.20.0)
# Requirement already satisfied: IPython in /home/naadi/.local/lib/python3.8/site-packages (7.18.1)
# Requirement already satisfied: pickleshare in /home/naadi/.local/lib/python3.8/site-packages (from IPython) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /home/naadi/.local/lib/python3.8/site-packages (from IPython) (5.0.4)
# Requirement already satisfied: jedi>=0.10 in /home/naadi/.local/lib/python3.8/site-packages (from IPython) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/naadi/.local/lib/python3.8/site-packages (from IPython) (3.0.7)
# Requirement already satisfied: pygments in /home/naadi/.local/lib/python3.8/site-packages (from IPython) (2.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from IPython) (45.2.0)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from IPython) (4.4.2)
# Requirement already satisfied: backcall in /home/naadi/.local/lib/python3.8/site-packages (from IPython) (0.2.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/lib/python3/dist-packages (from IPython) (4.6.0)
# Requirement already satisfied: ipython-genutils in /home/naadi/.local/lib/python3.8/site-packages (from traitlets>=4.2->IPython) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/naadi/.local/lib/python3.8/site-packages (from jedi>=0.10->IPython) (0.7.1)
# Requirement already satisfied: wcwidth in /home/naadi/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
